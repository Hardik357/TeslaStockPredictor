# %%
# !git clone https://github.com/Hardik357/python-youtube-code.git
# %cd python-youtube-code/
# %cd predicting-tesla-stock-price/
# Out:
# Cloning into 'python-youtube-code'...
# remote: Enumerating objects: 20239, done.
# remote: Total 20239 (delta 0), reused 0 (delta 0), pack-reused 20239
# Receiving objects: 100% (20239/20239), 195.70 MiB | 32.17 MiB/s, done.
# Resolving deltas: 100% (378/378), done.
# /content/python-youtube-code
# /content/python-youtube-code/predicting-tesla-stock-price

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime

# %%
tesla = pd.read_csv('/content/python-youtube-code/predicting-tesla-stock-price/TSLA.csv')
tesla = tesla[['Date','Close']]

tesla.Date = pd.to_datetime(tesla.Date, format = '%Y/%m/%d')
plot_tesla = tesla.set_index('Date')
plot_tesla['Close'].plot(figsize=(16,6))

# %%
tesla = tesla.loc[884:1639]
tesla.head()
# Out:
#           Date       Close
# 884 2014-01-02  150.100006
# 885 2014-01-03  149.559998
# 886 2014-01-06  147.000000
# 887 2014-01-07  149.360001
# 888 2014-01-08  151.279999

# %%
new_tesla = tesla.drop('Date', axis=1)
new_tesla = new_tesla.reset_index(drop=True)
T = new_tesla.values
T = T.astype('float32')
T = np.reshape(T, (-1, 1))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0,1))
T = scaler.fit_transform(T)

train_size = int(len(T) * 0.8)
test_size = int(len(T) - train_size)
train, test = T[0: train_size,:], T[train_size: len(T):]

# %%
def create_features(data, window_size):
    X, y = [],[]
    for i in range(len(data)-window_size - 1):
        window = data[i:(i+window_size), 0]
        X.append(window)
        y.append(data[i+window_size, 0])
    return np.array(X), np.array(y)

window_size = 20
X_train, y_train = create_features(train, window_size)
X_test, y_test = create_features(train, window_size)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
T_shape = T.shape
train_shape = train.shape
test_shape = test.shape

def is_leak(T_shape, test_shape, train_shape):
    return not(T_shape[0] == train_shape[0] + test_shape[0])

print(is_leak(T_shape, test_shape, train_shape))
# Out:
# False

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
tf.random.set_seed(11)
np.random.seed(11)

# %%
model = keras.Sequential()
model.add(layers.LSTM(units=50, activation='relu', input_shape=(X_train.shape[0], window_size)))
model.add(layers.Dropout(0.2))
model.add(layers.Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mse')

# %%
from keras.callbacks import ModelCheckpoint
filepath = 'saved_models/model_epoch_{epoch:02d}.hdf5'
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only = True,
                             mode='min')
history = model.fit(X_train, y_train, epochs=100, batch_size=20,validation_data=(X_test, y_test), callbacks=[checkpoint], verbose=1, shuffle=False)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Model was constructed with shape (None, 583, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 583, 20), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 20).
# WARNING:tensorflow:Model was constructed with shape (None, 583, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 583, 20), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 20).
# 23/30 [======================>.......] - ETA: 0s - loss: 0.3162 WARNING:tensorflow:Model was constructed with shape (None, 583, 20) for input KerasTensor(type_spec=TensorSpec(shape=(None, 583, 20), dtype=tf.float32, name='lstm_input'), name='lstm_input', description="created by layer 'lstm_input'"), but it was called on an input with incompatible shape (None, 1, 20).
# 30/30 [==============================] - 2s 13ms/step - loss: 0.2663 - val_loss: 0.0577
#
# Epoch 00001: val_loss improved from inf to 0.05774, saving model to saved_models/model_epoch_01.hdf5
# Epoch 2/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0312 - val_loss: 0.0128
#
# Epoch 00002: val_loss improved from 0.05774 to 0.01284, saving model to saved_models/model_epoch_02.hdf5
# Epoch 3/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0202 - val_loss: 0.0121
#
# Epoch 00003: val_loss improved from 0.01284 to 0.01210, saving model to saved_models/model_epoch_03.hdf5
# Epoch 4/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0195 - val_loss: 0.0110
#
# Epoch 00004: val_loss improved from 0.01210 to 0.01097, saving model to saved_models/model_epoch_04.hdf5
# Epoch 5/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0184 - val_loss: 0.0106
#
# Epoch 00005: val_loss improved from 0.01097 to 0.01055, saving model to saved_models/model_epoch_05.hdf5
# Epoch 6/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0172 - val_loss: 0.0095
#
# Epoch 00006: val_loss improved from 0.01055 to 0.00950, saving model to saved_models/model_epoch_06.hdf5
# Epoch 7/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0169 - val_loss: 0.0093
#
# Epoch 00007: val_loss improved from 0.00950 to 0.00933, saving model to saved_models/model_epoch_07.hdf5
# Epoch 8/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0168 - val_loss: 0.0083
#
# Epoch 00008: val_loss improved from 0.00933 to 0.00831, saving model to saved_models/model_epoch_08.hdf5
# Epoch 9/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0145 - val_loss: 0.0077
#
# Epoch 00009: val_loss improved from 0.00831 to 0.00770, saving model to saved_models/model_epoch_09.hdf5
# Epoch 10/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0150 - val_loss: 0.0073
#
# Epoch 00010: val_loss improved from 0.00770 to 0.00733, saving model to saved_models/model_epoch_10.hdf5
# Epoch 11/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0134 - val_loss: 0.0069
#
# Epoch 00011: val_loss improved from 0.00733 to 0.00687, saving model to saved_models/model_epoch_11.hdf5
# Epoch 12/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0120 - val_loss: 0.0076
#
# Epoch 00012: val_loss did not improve from 0.00687
# Epoch 13/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0128 - val_loss: 0.0065
#
# Epoch 00013: val_loss improved from 0.00687 to 0.00649, saving model to saved_models/model_epoch_13.hdf5
# Epoch 14/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0120 - val_loss: 0.0062
#
# Epoch 00014: val_loss improved from 0.00649 to 0.00618, saving model to saved_models/model_epoch_14.hdf5
# Epoch 15/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0117 - val_loss: 0.0059
#
# Epoch 00015: val_loss improved from 0.00618 to 0.00593, saving model to saved_models/model_epoch_15.hdf5
# Epoch 16/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0111 - val_loss: 0.0054
#
# Epoch 00016: val_loss improved from 0.00593 to 0.00544, saving model to saved_models/model_epoch_16.hdf5
# Epoch 17/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0108 - val_loss: 0.0050
#
# Epoch 00017: val_loss improved from 0.00544 to 0.00502, saving model to saved_models/model_epoch_17.hdf5
# Epoch 18/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0106 - val_loss: 0.0054
#
# Epoch 00018: val_loss did not improve from 0.00502
# Epoch 19/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0058
#
# Epoch 00019: val_loss did not improve from 0.00502
# Epoch 20/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0102 - val_loss: 0.0064
#
# Epoch 00020: val_loss did not improve from 0.00502
# Epoch 21/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0100 - val_loss: 0.0054
#
# Epoch 00021: val_loss did not improve from 0.00502
# Epoch 22/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0107 - val_loss: 0.0045
#
# Epoch 00022: val_loss improved from 0.00502 to 0.00450, saving model to saved_models/model_epoch_22.hdf5
# Epoch 23/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0096 - val_loss: 0.0042
#
# Epoch 00023: val_loss improved from 0.00450 to 0.00424, saving model to saved_models/model_epoch_23.hdf5
# Epoch 24/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0047
#
# Epoch 00024: val_loss did not improve from 0.00424
# Epoch 25/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0103 - val_loss: 0.0042
#
# Epoch 00025: val_loss improved from 0.00424 to 0.00421, saving model to saved_models/model_epoch_25.hdf5
# Epoch 26/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0104 - val_loss: 0.0045
#
# Epoch 00026: val_loss did not improve from 0.00421
# Epoch 27/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0043
#
# Epoch 00027: val_loss did not improve from 0.00421
# Epoch 28/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0092 - val_loss: 0.0049
#
# Epoch 00028: val_loss did not improve from 0.00421
# Epoch 29/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0096 - val_loss: 0.0059
#
# Epoch 00029: val_loss did not improve from 0.00421
# Epoch 30/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0044
#
# Epoch 00030: val_loss did not improve from 0.00421
# Epoch 31/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0087 - val_loss: 0.0042
#
# Epoch 00031: val_loss did not improve from 0.00421
# Epoch 32/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.0041
#
# Epoch 00032: val_loss improved from 0.00421 to 0.00414, saving model to saved_models/model_epoch_32.hdf5
# Epoch 33/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0090 - val_loss: 0.0044
#
# Epoch 00033: val_loss did not improve from 0.00414
# Epoch 34/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0089 - val_loss: 0.0047
#
# Epoch 00034: val_loss did not improve from 0.00414
# Epoch 35/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0049
#
# Epoch 00035: val_loss did not improve from 0.00414
# Epoch 36/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0094 - val_loss: 0.0049
#
# Epoch 00036: val_loss did not improve from 0.00414
# Epoch 37/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.0055
#
# Epoch 00037: val_loss did not improve from 0.00414
# Epoch 38/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.0054
#
# Epoch 00038: val_loss did not improve from 0.00414
# Epoch 39/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0085 - val_loss: 0.0051
#
# Epoch 00039: val_loss did not improve from 0.00414
# Epoch 40/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0043
#
# Epoch 00040: val_loss did not improve from 0.00414
# Epoch 41/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0088 - val_loss: 0.0042
#
# Epoch 00041: val_loss did not improve from 0.00414
# Epoch 42/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.0039
#
# Epoch 00042: val_loss improved from 0.00414 to 0.00392, saving model to saved_models/model_epoch_42.hdf5
# Epoch 43/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0035
#
# Epoch 00043: val_loss improved from 0.00392 to 0.00352, saving model to saved_models/model_epoch_43.hdf5
# Epoch 44/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0091 - val_loss: 0.0036
#
# Epoch 00044: val_loss did not improve from 0.00352
# Epoch 45/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.0035
#
# Epoch 00045: val_loss improved from 0.00352 to 0.00345, saving model to saved_models/model_epoch_45.hdf5
# Epoch 46/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0082 - val_loss: 0.0037
#
# Epoch 00046: val_loss did not improve from 0.00345
# Epoch 47/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0084 - val_loss: 0.0063
#
# Epoch 00047: val_loss did not improve from 0.00345
# Epoch 48/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0077 - val_loss: 0.0049
#
# Epoch 00048: val_loss did not improve from 0.00345
# Epoch 49/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0046
#
# Epoch 00049: val_loss did not improve from 0.00345
# Epoch 50/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0088 - val_loss: 0.0045
#
# Epoch 00050: val_loss did not improve from 0.00345
# Epoch 51/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0081 - val_loss: 0.0041
#
# Epoch 00051: val_loss did not improve from 0.00345
# Epoch 52/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0080 - val_loss: 0.0055
#
# Epoch 00052: val_loss did not improve from 0.00345
# Epoch 53/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0073 - val_loss: 0.0043
#
# Epoch 00053: val_loss did not improve from 0.00345
# Epoch 54/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0042
#
# Epoch 00054: val_loss did not improve from 0.00345
# Epoch 55/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0076 - val_loss: 0.0034
#
# Epoch 00055: val_loss improved from 0.00345 to 0.00339, saving model to saved_models/model_epoch_55.hdf5
# Epoch 56/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0032
#
# Epoch 00056: val_loss improved from 0.00339 to 0.00323, saving model to saved_models/model_epoch_56.hdf5
# Epoch 57/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0083 - val_loss: 0.0042
#
# Epoch 00057: val_loss did not improve from 0.00323
# Epoch 58/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.0037
#
# Epoch 00058: val_loss did not improve from 0.00323
# Epoch 59/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0072 - val_loss: 0.0039
#
# Epoch 00059: val_loss did not improve from 0.00323
# Epoch 60/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0080 - val_loss: 0.0056
#
# Epoch 00060: val_loss did not improve from 0.00323
# Epoch 61/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0074 - val_loss: 0.0038
#
# Epoch 00061: val_loss did not improve from 0.00323
# Epoch 62/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0075 - val_loss: 0.0040
#
# Epoch 00062: val_loss did not improve from 0.00323
# Epoch 63/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0066 - val_loss: 0.0036
#
# Epoch 00063: val_loss did not improve from 0.00323
# Epoch 64/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0069 - val_loss: 0.0034
#
# Epoch 00064: val_loss did not improve from 0.00323
# Epoch 65/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0071 - val_loss: 0.0033
#
# Epoch 00065: val_loss did not improve from 0.00323
# Epoch 66/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0035
#
# Epoch 00066: val_loss did not improve from 0.00323
# Epoch 67/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0077 - val_loss: 0.0030
#
# Epoch 00067: val_loss improved from 0.00323 to 0.00295, saving model to saved_models/model_epoch_67.hdf5
# Epoch 68/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0032
#
# Epoch 00068: val_loss did not improve from 0.00295
# Epoch 69/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0071 - val_loss: 0.0032
#
# Epoch 00069: val_loss did not improve from 0.00295
# Epoch 70/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0068 - val_loss: 0.0038
#
# Epoch 00070: val_loss did not improve from 0.00295
# Epoch 71/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0066 - val_loss: 0.0031
#
# Epoch 00071: val_loss did not improve from 0.00295
# Epoch 72/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0065 - val_loss: 0.0034
#
# Epoch 00072: val_loss did not improve from 0.00295
# Epoch 73/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0035
#
# Epoch 00073: val_loss did not improve from 0.00295
# Epoch 74/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0030
#
# Epoch 00074: val_loss did not improve from 0.00295
# Epoch 75/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0068 - val_loss: 0.0030
#
# Epoch 00075: val_loss did not improve from 0.00295
# Epoch 76/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0068 - val_loss: 0.0033
#
# Epoch 00076: val_loss did not improve from 0.00295
# Epoch 77/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0062 - val_loss: 0.0030
#
# Epoch 00077: val_loss did not improve from 0.00295
# Epoch 78/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0061 - val_loss: 0.0033
#
# Epoch 00078: val_loss did not improve from 0.00295
# Epoch 79/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0067 - val_loss: 0.0035
#
# Epoch 00079: val_loss did not improve from 0.00295
# Epoch 80/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.0032
#
# Epoch 00080: val_loss did not improve from 0.00295
# Epoch 81/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0061 - val_loss: 0.0042
#
# Epoch 00081: val_loss did not improve from 0.00295
# Epoch 82/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0055 - val_loss: 0.0032
#
# Epoch 00082: val_loss did not improve from 0.00295
# Epoch 83/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0060 - val_loss: 0.0034
#
# Epoch 00083: val_loss did not improve from 0.00295
# Epoch 84/100
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0061 - val_loss: 0.0029
#
# Epoch 00084: val_loss improved from 0.00295 to 0.00286, saving model to saved_models/model_epoch_84.hdf5
# Epoch 85/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0059 - val_loss: 0.0028
#
# Epoch 00085: val_loss improved from 0.00286 to 0.00278, saving model to saved_models/model_epoch_85.hdf5
# Epoch 86/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0060 - val_loss: 0.0028
#
# Epoch 00086: val_loss did not improve from 0.00278
# Epoch 87/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0028
#
# Epoch 00087: val_loss did not improve from 0.00278
# Epoch 88/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0025
#
# Epoch 00088: val_loss improved from 0.00278 to 0.00251, saving model to saved_models/model_epoch_88.hdf5
# Epoch 89/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0026
#
# Epoch 00089: val_loss did not improve from 0.00251
# Epoch 90/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.0029
#
# Epoch 00090: val_loss did not improve from 0.00251
# Epoch 91/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0027
#
# Epoch 00091: val_loss did not improve from 0.00251
# Epoch 92/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0054 - val_loss: 0.0033
#
# Epoch 00092: val_loss did not improve from 0.00251
# Epoch 93/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0026
#
# Epoch 00093: val_loss did not improve from 0.00251
# Epoch 94/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0057 - val_loss: 0.0034
#
# Epoch 00094: val_loss did not improve from 0.00251
# Epoch 95/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0055 - val_loss: 0.0029
#
# Epoch 00095: val_loss did not improve from 0.00251
# Epoch 96/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0027
#
# Epoch 00096: val_loss did not improve from 0.00251
# Epoch 97/100
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0051 - val_loss: 0.0025
#
# Epoch 00097: val_loss improved from 0.00251 to 0.00248, saving model to saved_models/model_epoch_97.hdf5
# Epoch 98/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0056 - val_loss: 0.0039
#
# Epoch 00098: val_loss did not improve from 0.00248
# Epoch 99/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0032
#
# Epoch 00099: val_loss did not improve from 0.00248
# Epoch 100/100
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0046 - val_loss: 0.0024
#
# Epoch 00100: val_loss improved from 0.00248 to 0.00235, saving model to saved_models/model_epoch_100.hdf5

# %%
from keras.models import load_model
best_model = load_model('saved_models/model_epoch_89.hdf5')

train_predict = best_model.predict(X_train)
y_hat_train = scaler.inverse_transform(train_predict)
test_predict = best_model.predict(X_test)
y_hat_test = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])
y_train = scaler.inverse_transform([y_train])

# %%
y = np.append(y_train, y_test)
y_hat = np.append(y_hat_train, y_hat_test)

result_df = pd.DataFrame()

result_df['Actual_Y'] = y
result_df['Predicted_Y'] = y_hat


result_df.head()
# Out:
#      Actual_Y  Predicted_Y
# 0  181.410008   190.035355
# 1  177.110005   190.094711
# 2  178.729989   187.177917
# 3  174.420000   187.175049
# 4  178.380001   186.330902

# %%
result_df.plot()
